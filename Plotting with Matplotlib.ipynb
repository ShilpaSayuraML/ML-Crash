# %%
import matplotlib.pyplot as plt
plt.plot([1,1])

# %%
plt.plot([1,1])
plt.plot([2,2])
plt.plot([3,3])

# %%
plt.figure(1)
plt.plot([1,1])
plt.figure(2)
plt.plot([1,2])

# %%
plt.plot([1,2,1,2])
plt.title('GRID REPRESENTATION')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
plt.plot([1,2,1,2])
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid()

# %%
#subplot() plots multiple plots in the same figure.
plt.subplot(2,1,1)
plt.plot([1,4])
plt.subplot(2,1,2)
plt.plot([2,2])

# %%
# Histogram Plot
# probability distribution 

days = [40,30,70,80,40,20,20,20,70,20,60,20,80,50,40,50,20,60,60,60]
bins = [0,10,20,40,50,60,70,80,90,100]
plt.hist(days, bins, histtype='stepfilled', rwidth=0.88)
plt.xlabel('Distance in kms')
plt.ylabel('kilometer count')
plt.title('bike details Histogram')
# Out:
# Text(0.5, 1.0, 'bike details Histogram')

# %%
#Line Plots

x = [1,2,3,4,5]
y = [50,40,70,80,20]
y2 = [80,20,20,50,60]
y3 = [70,20,60,40,60]
y4 = [80,20,20,50,60]
plt.plot(x,y,'r',label='Susuki', linewidth=2)
plt.plot(x,y2,'c',label='Honda',linewidth=2)
plt.plot(x,y3,'k',label='Yahama',linewidth=2)
plt.plot(x,y4,'y',label='Ducati',linewidth=2)

plt.title('Bike details in line plot')
plt.ylabel('Distance in kms')
plt.xlabel('Days')
plt.legend()

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
import matplotlib.pyplot as plt
plt.bar([0.25,1.25,2.25,3.25,4.25],[50,40,70,80,20],
label="Susuki",width=.5)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar([0.26,1.25,2.25,3.25,4.25],[80,20,20,50,60],
label='Honda', color='r',width=.2)
plt.bar([0.31,1.5,2.5,3.5,4.5],[70,20,60,40,60],
label='Yamaha', color='y',width=.2)
plt.bar([.75,1.75,2.75,3.75,4.75],[80,20,20,50,60],
label='KTM', color='g',width=.2)
plt.legend()
plt.xlabel('Days')
plt.ylabel('Distance (kms)')
plt.title('Bikes details in BAR PLOTTING')
# Out:
# Text(0.5, 1.0, 'Bikes details in BAR PLOTTING')

# %%
#Area Plot

days = [1,2,3,4,5]
Enfield =[50,40,70,80,20]
Honda = [80,20,20,50,60]
Yahama =[70,20,60,40,60]
KTM = [80,20,20,50,60]
plt.plot([],[],color='k', label='Susu', linewidth=5)
plt.plot([],[],color='c', label='Honda', linewidth=5)
plt.plot([],[],color='y', label='Yahama', linewidth=5)
plt.plot([],[],color='m', label='KTM', linewidth=5)
plt.stackplot(days, Enfield, Honda, Yahama, KTM, colors=['k','c','y','m'])
plt.xlabel('Days')
plt.ylabel('Distance in kms')
plt.title('Bikes deatils in area plot')
plt.legend()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('caldata.csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
#Pie Plot

days = [1,2,3,4,5]
Susuki =[50,40,70,80,20]
Honda = [80,20,20,50,60]
Yahama =[70,20,60,40,60]
KTM = [80,20,20,50,60]

slices = [8,5,5,6]
activities = ['Susuki','Honda','Yahama','Ducati']
cols = ['c','g','y','b']
plt.pie(slices,
labels=activities,
colors=cols,
startangle=90,
shadow= True,
explode=(0,0.1,0,0),
autopct='%1.1f%%')
plt.title('Bike details in Pie Plot')
# Out:
# Text(0.5, 1.0, 'Bike details in Pie Plot')

# %%
days = [1, 2, 3, 4, 5]
Y1 = [50, 40, 70, 80, 20]
Y2=[80, 20, 20, 50, 60]
Y3=[70, 20, 60, 40, 60]
Y4=[80, 20, 20, 50, 60]

plt.scatter(days,Y1, label='Enfield',color='r')
plt.scatter(days,Y2,label='Honda',color='b')
plt.scatter(days,Y3,label='Yahama',color='y')
plt.scatter(days,Y4,label='KTM',color='k')
plt.xlabel('Days')
plt.ylabel('Distance in kms')
plt.title(' Bike details in Scatter Plot')
plt.legend()

# %%
#3D Plot

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = [1,2,3,4,5]
y = [50,40,70,80,20]
y2 = [80,20,20,50,60]
y3 = [70,20,60,40,60]
y4 = [80,20,20,50,60]
plt.plot(x,y,'g',label='Enfield', linewidth=5)
plt.plot(x,y2,'c',label='Honda',linewidth=5)
plt.plot(x,y3,'k',label='Yahama',linewidth=5)
plt.plot(x,y4,'y',label='KTM',linewidth=5)
plt.title('bike details in line plot')
plt.ylabel(' Distance in kms')
plt.xlabel('Days')
plt.legend()

# %%
plt.scatter(days,Y1, label='Enfield',color='r')
plt.scatter(days,Y2,label='Honda',color='b')
plt.scatter(days,Y3,label='Yahama',color='y')
plt.scatter(days,Y4,label='KTM',color='k')
plt.xlabel('Days')
plt.ylabel('Distance in kms')
plt.title(' Bike details in Scatter Plot')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [39], line 1
# ----> 1 plt.scatter(days,Y1, label='Enfield',color='r')
#       2 plt.scatter(days,Y2,label='Honda',color='b')
#       3 plt.scatter(days,Y3,label='Yahama',color='y')
#
# NameError: name 'Y1' is not defined

# %%
df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')
# Out:
# <AxesSubplot: xlabel='Duration', ylabel='Calories'>

# %%
df.plot(kind = 'scatter', x = 'Duration', y = 'Maxpulse')
# Out:
# <AxesSubplot: xlabel='Duration', ylabel='Maxpulse'>

# %% [markdown]
# ## Satistical distributions

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import normaltest

# %%
# Create a dataset of normally distributed data
d1 = stats.norm.rvs(size=100000)

# %%
d1[:5]
# Out:
# array([ 1.77545818,  0.92578843, -1.53609193, -1.17409654, -0.91838504])

# %%
# Plot a histogram of the observed data
#  Included is expected distribution, if the data is normally distributed, with the same mean and std of the data. 
xs = np.arange(d1.min(), d1.max(), 0.1)
fit = stats.norm.pdf(xs, np.mean(d1), np.std(d1))
plt.plot(xs, fit, label='Normal Dist.', lw=3)
plt.hist(d1, 50, density=True, label='Actual Data');
plt.legend();

# %%
#Non normal distribution

# Generate some data from a beta distribution
d2 = stats.beta.rvs(7, 10, size=100000)
# Plot a histogram of the observed data
plt.hist(d2, 50, density=True, color='C1', label='Actual Data');
plt.legend();

# %%
# Plot the data with with expected distribution, under the hypothesis that it is normally distributed. 
#  The blue line is the expected data density, with the same mean and standard deviation, if the data are normal. 
xs = np.arange(d2.min(), d2.max(), 0.01)
fit = stats.norm.pdf(xs, np.mean(d2), np.std(d2))
plt.plot(xs, fit, label='Normal Dist.', lw=3)
plt.hist(d2, 50, density=True, label='Actual Data');
plt.legend();
