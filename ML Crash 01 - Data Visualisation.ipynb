# %% [markdown]
# ## ML Crash Course

# %% [markdown]
# **Numpy**

# %%
# define an array
import numpy
mylist = [1, 2, 3]
myarray = numpy.array(mylist)
print(myarray)
print(myarray.shape)
# Out:
# [1 2 3]
# (3,)

# %%
#Access Data
#Array notation and ranges can be used to access data in a NumPy array.
# access values
import numpy
mylist = [[1, 2, 3], [3, 4, 5]]
myarray = numpy.array(mylist)
print(myarray)
print(myarray.shape)
# Out:
# [[1 2 3]
#  [3 4 5]]
# (2, 3)

# %%
print(myarray[0])
print(myarray[-1])
print(myarray[0, 2])
print(myarray[:, 2])
# Out:
# [1 2 3]
# [3 4 5]
# 3
# [3 5]

# %% [markdown]
# **Arithmetic**

# %%
# arithmetic
myarray1 = numpy.array([1, 2, 3])
myarray2 = numpy.array([2, 3, 3])
print(myarray1[0] + myarray2[1])
print(myarray1 + myarray2)
print(myarray1 * myarray2)
# Out:
# 4
# [3 5 6]
# [2 6 9]

# %% [markdown]
# **Matplotlib**

# %%
import matplotlib.pyplot as plt
import numpy
X = numpy.array([1, 2, 3])
Y = numpy.array([2, 4, 6])

plt.plot(X, Y)
plt.xlabel('x axis')
plt.ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %% [markdown]
# **Scatter Plot**

# %%
import matplotlib.pyplot as plt
import numpy

x = numpy.array([6, 3, 3])
y = numpy.array([7, 4, 6])

plt.scatter(x,y)
plt.xlabel('some x axis')
plt.ylabel('some y axis')
# Out:
# Text(0, 0.5, 'some y axis')

# %% [markdown]
# **Series**<br>
# A series is a one dimensional array <br>
# The rows and columns can be labeled.

# %%
import numpy as np
import pandas as pd
myarray = np.array([1, 2, 3])
rownames = ['a', 'b', 'c']
myseries = pd.Series(myarray, index=rownames)
print(myseries)
# Out:
# a    1
# b    2
# c    3
# dtype: int32

# %% [markdown]
# ## DataFrame
# A data frame is a multi-dimensional array where the rows and the columns can be labeled.

# %%
# dataframe
import numpy
import pandas
myarray = numpy.array([[1, 2, 3], [4, 5, 6]])
rownames = ['a', 'b']
colnames = ['one', 'two', 'three']
mydataframe = pandas.DataFrame(myarray, index=rownames, columns=colnames)
print(mydataframe)
# Out:
#    one  two  three
# a    1    2      3
# b    4    5      6

# %%
#Data can be index using column names.
print(mydataframe['one'])
print(mydataframe.one)
# Out:
# a    1
# b    4
# Name: one, dtype: int32
# a    1
# b    4
# Name: one, dtype: int32

# %% [markdown]
# ## Load CSV Files

# %%
from numpy import genfromtxt
filename = 'diabetes.csv'
my_data = genfromtxt(filename, delimiter=',')
print(my_data)
my_data.shape
# Out:
# [[    nan     nan     nan ...     nan     nan     nan]
#  [  6.    148.     72.    ...   0.627  50.      1.   ]
#  [  1.     85.     66.    ...   0.351  31.      0.   ]
#  ...
#  [  5.    121.     72.    ...   0.245  30.      0.   ]
#  [  1.    126.     60.    ...   0.349  47.      1.   ]
#  [  1.     93.     70.    ...   0.315  23.      0.   ]]
# (769, 9)

# %%
my_data[1:4]
# Out:
# array([[  6.   , 148.   ,  72.   ,  35.   ,   0.   ,  33.6  ,   0.627,
#          50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   ,  29.   ,   0.   ,  26.6  ,   0.351,
#          31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   ,   0.   ,   0.   ,  23.3  ,   0.672,
#          32.   ,   1.   ]])

# %%
from numpy import genfromtxt
filename = 'diabetes.csv'
my_data = genfromtxt(filename, delimiter=',')
print(my_data)
my_data.shape
# Out:
# [[    nan     nan     nan ...     nan     nan     nan]
#  [  6.    148.     72.    ...   0.627  50.      1.   ]
#  [  1.     85.     66.    ...   0.351  31.      0.   ]
#  ...
#  [  5.    121.     72.    ...   0.245  30.      0.   ]
#  [  1.    126.     60.    ...   0.349  47.      1.   ]
#  [  1.     93.     70.    ...   0.315  23.      0.   ]]
# (769, 9)

# %%
# Load CSV from URL using Pandas
import pandas as pd

url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
c=pd.read_csv(url)
c.head(5)
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# **Load CSV using Pandas**

# %%
from pandas import read_csv
filename = 'diabetes.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(filename, names=names)
print(data.shape)
print(data.tail(5))
# Out:
# (769, 9)
#     preg plas pres skin test  mass   pedi age class
# 764   10  101   76   48  180  32.9  0.171  63     0
# 765    2  122   70   27    0  36.8   0.34  27     0
# 766    5  121   72   23  112  26.2  0.245  30     0
# 767    1  126   60    0    0  30.1  0.349  47     1
# 768    1   93   70   31    0  30.4  0.315  23     0

# %%
#data types
types = data.dtypes
print(types)
# Out:
# preg     object
# plas     object
# pres     object
# skin     object
# test     object
# mass     object
# pedi     object
# age      object
# class    object
# dtype: object

# %% [markdown]
# ## Satistical Summery

# %%
description = data.describe()
print(description)
# Out:
#        preg plas pres skin test mass   pedi  age class
# count   769  769  769  769  769  769    769  769   769
# unique   18  137   48   52  187  249    518   53     3
# top       1  100   70    0    0   32  0.254   22     0
# freq    135   17   57  227  374   13      6   72   500

# %%
# Create a Series
numericSeries = pd.Series([1,4,6,53,2,2,1,1])
# Apply describe function
numericSeries.describe()
# Out:
# count     8.000000
# mean      8.750000
# std      17.966238
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       4.500000
# max      53.000000
# dtype: float64

# %%
from pandas import read_csv
filename = 'diabetes1.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data1 = read_csv(filename, names=names)
print(data1.shape)
print(data1.tail(5))
# Out:
# (768, 9)
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0

# %%
types = data1.dtypes
print(types)
# Out:
# preg       int64
# plas       int64
# pres       int64
# skin       int64
# test       int64
# mass     float64
# pedi     float64
# age        int64
# class      int64
# dtype: object

# %%
data1.describe()
# Out:
#              preg        plas        pres        skin        test        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
#On classification problems you need to know how balanced the class values are
class_counts = data.groupby('class').size()
print(class_counts)
# Out:
# class
# 0          500
# 1          268
# Outcome      1
# dtype: int64

# %% [markdown]
# ## Correlations Between Attributes
# Correlation is the relationship between two variables and how they may or may not change together. <br>
#
# Pearson’s Correlation Coefficient, that assumes a normal distribution of the attributes involved. <br>
# A correlation of -1 or 1 shows a full negative or positive correlation. Whereas a value of 0 shows no correlation at all.
# <br>
# Some machine learning algorithms like linear and logistic regression can suffer  poor performance if there are highly correlated attributes in the dataset.

# %%
#Calculate correlation matrix using corr() function in Pandas DataFrame .

# Pairwise Pearson correlations
from pandas import read_csv
from pandas import set_option
filename = "diabetes1.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(filename, names=names)
correlations = data.corr(method='pearson')
print(correlations)
# Out:
#            preg      plas      pres      skin      test      mass      pedi  \
# preg   1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523
# plas   0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337
# pres   0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265
# skin  -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928
# test  -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071
# mass   0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647
# pedi  -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000
# age    0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561
# class  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844
#
#             age     class
# preg   0.544341  0.221898
# plas   0.263514  0.466581
# pres   0.239528  0.065068
# skin  -0.113970  0.074752
# test  -0.042163  0.130548
# mass   0.036242  0.292695
# ...

# %% [markdown]
# give correlation between all pairs of attributes (twice, the matrix is symmetrical), as well as check the diagonal.

# %% [markdown]
# ## Skew of Univariate Distributions
# Skew refers to a distribution that is assumed Gaussian (normal or bell curve) that is shifted or squashed in one direction or another.<br>
#
# Many machine learning algorithms assume a Gaussian
# distribution. Calculate the skew to correct and later improve the accuracy of your models.

# %% [markdown]
# https://itfeature.com/statistics/skewness-and-measures-of-skewness

# %%
# Skew for each attribute
from pandas import read_csv
filename = "diabetes1.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(filename, names=names)
skew = data.skew()
print(skew)
# Out:
# preg     0.901674
# plas     0.173754
# pres    -1.843608
# skin     0.109372
# test     2.272251
# mass    -0.428982
# pedi     1.919911
# age      1.129597
# class    0.635017
# dtype: float64

# %%
data['preg'].hist()
# Out:
# <AxesSubplot: >

# %%
histograms = data.hist(figsize=(16,8))

# %%
# Univariate Density Plots
# an abstracted histogram with a smooth curv
data.plot(kind='density', subplots=True, layout=(3,3), sharex=False)
# Out:
# array([[<AxesSubplot: ylabel='Density'>, <AxesSubplot: ylabel='Density'>,
#         <AxesSubplot: ylabel='Density'>],
#        [<AxesSubplot: ylabel='Density'>, <AxesSubplot: ylabel='Density'>,
#         <AxesSubplot: ylabel='Density'>],
#        [<AxesSubplot: ylabel='Density'>, <AxesSubplot: ylabel='Density'>,
#         <AxesSubplot: ylabel='Density'>]], dtype=object)

# %% [markdown]
# ## Box and Whisker Plots
# #Boxplots summarize the distribution of each attribute
# drawing a line on median (middle value) and a box around the 25th and 75th percentiles (the middle 50% of
# the data)<br>
# The whiskers give an idea of the spread of the data <br>
# dots outside of the whiskers show candidate outlier values (values that are 1.5 times greater than the size of spread of the
# middle 50% of the data).<br>

# %%
data.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False)
# Out:
# preg        AxesSubplot(0.125,0.653529;0.227941x0.226471)
# plas     AxesSubplot(0.398529,0.653529;0.227941x0.226471)
# pres     AxesSubplot(0.672059,0.653529;0.227941x0.226471)
# skin        AxesSubplot(0.125,0.381765;0.227941x0.226471)
# test     AxesSubplot(0.398529,0.381765;0.227941x0.226471)
# mass     AxesSubplot(0.672059,0.381765;0.227941x0.226471)
# pedi            AxesSubplot(0.125,0.11;0.227941x0.226471)
# age          AxesSubplot(0.398529,0.11;0.227941x0.226471)
# class        AxesSubplot(0.672059,0.11;0.227941x0.226471)
# dtype: object

# %% [markdown]
# Correlation gives an indication of how related the changes are between two variables. If two
# variables change in the same direction they are positively correlated. If they change in opposite
# directions together (one goes up, one goes down), then they are negatively correlated. You can
# calculate the correlation between each pair of attributes. This is called a correlation matrix.

# %%
# Correction Matrix Plot
from matplotlib import pyplot
correlations = data.corr()
# plot correlation matrix
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
pyplot.show()

# %% [markdown]
# ## Scatter Plot Matrix
# A scatter plot shows the relationship between two variables as dots in two dimensions, one axis for each attribute. <br>
#
# You can create a scatter plot for each pair of attributes in your data.

# %%
pd.plotting.scatter_matrix(data, alpha=0.2)
pyplot.show()
